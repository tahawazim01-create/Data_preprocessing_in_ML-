# %% [markdown]
# <a href="https://colab.research.google.com/github/tahawazim01-create/Data_preprocessing_in_ML-/blob/main/tranforming_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

df = pd.DataFrame({
    'Age' : [20 , 21, 30, 28],
    'Salary' : [100000, 200000, 90000, 50000]
})
print(df)

""" Standardization """

standard_scaler = StandardScaler()
# df_standardized = standard_scaler.fit_transform(df)
# print(df_standardized)

df_standardized = pd.DataFrame(standard_scaler.fit_transform(df), columns=df.columns)
print("\nStandardized Data")
print(df_standardized)

"""Normalization"""

# minmaxscaler = MinMaxScaler()
# df_Normalized = pd.DataFrame(minmaxscaler.fit_transform(df), columns=df.columns)
# print("Normalized Data")
# print(df_Normalized)
# Out:
#    Age  Salary
# 0   20  100000
# 1   21  200000
# 2   30   90000
# 3   28   50000
#
# Standardized Data
#         Age    Salary
# 0 -1.098798 -0.181071
# 1 -0.867472  1.629643
# 2  1.214461 -0.362143
# 3  0.751809 -1.086429
# 'Normalization'
